# %% [markdown]
# Compare the band structures obtained by empirical pseudopotentials to those by VASP.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
lattice_type = "simple_cubic"
lattice_constants = [1,1,2]

if lattice_type == "simple_cubic":
    if not (lattice_constants[0] == lattice_constants[1] ==
            lattice_constants[2]):
        msg = ("The lattice constants should all be the same for a simple-"
                "cubic lattice")
        raise ValueError(msg.format(lattice_constants))

    a = lattice_constants[0]
    a1 = [a, 0, 0]
    a2 = [0, a, 0]
    a3 = [0, 0, a]
    lattice_vectors = np.transpose(np.array([a1, a2, a3], dtype=float))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9796e1494b99> in <module>()
#       8         msg = ("The lattice constants should all be the same for a simple-"
#       9                 "cubic lattice")
# ---> 10         raise ValueError(msg.format(lattice_constants))
#      11
#      12     a = lattice_constants[0]
#
# ValueError: The lattice constants should all be the same for a simple-cubic lattice

# %%
from BZI.plots import PlotBandStructure, PlotVaspBandStructure
from BZI.pseudopots import *

# %%
Al_params = {"materials_list": ["Al"],
             "PPlist": [Al_PP],
             "PPargs_list": [{}],
             "lat_consts": [Al_lat_const]*3,
             "lat_centering": Al_lat_centering,
             "lat_angles": Al_lat_angles,
             "lat_type": Al_lat_type,
             "sympt_pairs": [("G","X"),("X","W"),("W","L"),("L","G"),("G","K")],
             "npts": 20,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
             "show": True
}

PlotBandStructure(**Al_params)

# %%
Cu_params = {"materials_list": ["Cu"],
             "PPlist": [Cu_PP],
             "PPargs_list": [{}],
             "lat_type": "fcc",
             "lat_const": Cu_lat_const,
             "sympt_pairs": [("G","X"),("X","W"),("W","L"),("L","G"),("G","K")],
             "npts": 20,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
}

PlotBandStructure(**Cu_params)

# %%
Ag_params = {"materials_list": ["Ag"],
             "PPlist": [Ag_PP],
             "PPargs_list": [{}],
             "lat_type": "fcc",
             "lat_const": Ag_lat_const,
             "sympt_pairs": [("G","X"),("X","W"),("W","L"),("L","G"),("G","K")],
             "npts": 20,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
}

PlotBandStructure(**Ag_params)

# %%
Au_params = {"materials_list": ["Au"],
             "PPlist": [Au_PP],
             "PPargs_list": [{}],
             "lat_type": "fcc",
             "lat_const": Au_lat_const,
             "sympt_pairs": [("G","X"),("X","W"),("W","L"),("L","G"),("G","K")],
             "npts": 20,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
}

PlotBandStructure(**Au_params)

# %%
Pb_params = {"materials_list": ["Pb"],
             "PPlist": [Pb_PP],
             "PPargs_list": [{}],
             "lat_type": "fcc",
             "lat_const": Pb_lat_const,
             "sympt_pairs": [("G","X"),("X","W"),("W","L"),("L","G"),("G","K")],
             "npts": 40,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
}

PlotBandStructure(**Pb_params)

# %%
Li_params = {"materials_list": ["Li"],
             "PPlist": [Li_PP],
             "PPargs_list": [{}],
             "lat_type": "bcc",
             "lat_const": Li_lat_const,
             "sympt_pairs": [("G","H"),("H","N"),("N","G"),("G","P")],
             "npts": 40,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
}

PlotBandStructure(**Li_params)

# %%
Na_params = {"materials_list": ["Na"],
             "PPlist": [Na_PP],
             "PPargs_list": [{}],
             "lat_type": "bcc",
             "lat_const": Na_lat_const,
             "sympt_pairs": [("G","H"),("H","N"),("N","G"),("G","P")],
             "npts": 40,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-5,30],
}

PlotBandStructure(**Na_params)

# %%
K_params = {"materials_list": ["K"],
             "PPlist": [K_PP],
             "PPargs_list": [{}],
             "lat_type": "bcc",
             "lat_const": K_lat_const,
             "sympt_pairs": [("G","H"),("H","N"),("N","G"),("G","P")],
             "npts": 40,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-1,5],
}

PlotBandStructure(**K_params)

# %%
Rb_params = {"materials_list": ["Rb"],
             "PPlist": [Rb_PP],
             "PPargs_list": [{}],
             "lat_type": "bcc",
             "lat_const": Rb_lat_const,
             "sympt_pairs": [("G","H"),("H","N"),("N","G"),("G","P")],
             "npts": 40,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-1,15],
}

PlotBandStructure(**Rb_params)

# %%
Cs_params = {"materials_list": ["Cs"],
             "PPlist": [Cs_PP],
             "PPargs_list": [{}],
             "lat_type": "bcc",
             "lat_const": Cs_lat_const,
             "sympt_pairs": [("G","H"),("H","N"),("N","G"),("G","P")],
             "npts": 40,
             "neigvals": 10,
             "energy_shift": 0.0,
             "elimits": [-1,15],
}

PlotBandStructure(**Cs_params)
